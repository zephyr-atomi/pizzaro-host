# %%
from pizzaro.gateway import send_command, wait_for_stepper_available, system_reset, make_pie_base, add_ketchup, add_cheese
import socket
import logging
import asyncio
import threading
import random
import time

s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect(("127.0.0.1", 9999))

# %%
async def make_a_pizza(s):
    await make_pie_base(s)
    await add_ketchup(s)
    await add_cheese(s)

await make_a_pizza(s)
# Out:
# REQ:  b'{"command": "hpd move_to 56800"}'
# RESP:  b'{"Hpd":"HpdAck"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# REQ:  b'{"command": "hpd wait_idle"}'
# RESP:  b'{"AtomiError":"HpdUnavailable"}'
# ...
