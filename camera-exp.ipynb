# %%
import cv2
cv2.version
# Out:
# <module 'cv2.version' from '/home/lamuguo/venv/pizzaro/lib/python3.10/site-packages/cv2/version.py'>

# %%
import cv2

# 打开摄像头
cap = cv2.VideoCapture(0)  # 使用0作为参数表示打开默认的USB摄像头

while True:
    # 读取一帧图像
    ret, frame = cap.read()

    if ret:
        # 在窗口中显示图像
        cv2.imshow('USB Camera', frame)

        # 按下'q'键退出循环
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# 释放摄像头并关闭窗口
cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@103.463] global cap_v4l.cpp:1134 tryIoctl VIDEOIO(V4L2:/dev/video0): select() timeout.

# %%
import cv2

# 加载人脸检测的级联分类器
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# 打开摄像头
cap = cv2.VideoCapture(0)

while True:
    # 读取一帧图像
    ret, frame = cap.read()

    if ret:
        # 将图像转换为灰度图
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # 检测人脸
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        
        # 在检测到的人脸周围绘制矩形框
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
        # 显示处理后的帧
        cv2.imshow('Face Detection', frame)
        
        # 按下'q'键退出循环
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# 释放摄像头并关闭窗口
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import time
import os

# 设置保存图片的目录
output_dir = 'captured_images'
os.makedirs(output_dir, exist_ok=True)

# 打开摄像头
cap = cv2.VideoCapture(0)
exposure_time = 1/100
cap.set(cv2.CAP_PROP_EXPOSURE, exposure_time)

# 设置抓取图片的时间间隔(秒)
capture_interval = 1

# 记录上一次抓取图片的时间
last_capture_time = time.time()

# 图片编号计数器
image_counter = 1

while True:
    if image_counter >= 10000:
        break

    # 读取一帧图像
    ret, frame = cap.read()

    if ret:
        # 获取当前时间
        current_time = time.time()

        # 检查是否达到抓取图片的时间间隔
        if current_time - last_capture_time >= capture_interval:
            # 生成图片文件名
            image_name = f'pizza03_{image_counter:04d}.jpg'
            image_path = os.path.join(output_dir, image_name)

            # 保存抓取的图片
            cv2.imwrite(image_path, frame)

            print(f'Captured image: {image_name}')

            # 更新上一次抓取图片的时间
            last_capture_time = current_time

            # 增加图片编号计数器
            image_counter += 1

        # 显示当前帧
        # cv2.imshow('USB Camera', frame)

        # 按下'q'键退出循环
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# 释放摄像头并关闭窗口
cap.release()
cv2.destroyAllWindows()
# Out:
# Captured image: pizza03_0001.jpg
# Captured image: pizza03_0002.jpg
# Captured image: pizza03_0003.jpg
# Captured image: pizza03_0004.jpg
# Captured image: pizza03_0005.jpg
# Captured image: pizza03_0006.jpg
# Captured image: pizza03_0007.jpg
# Captured image: pizza03_0008.jpg
# Captured image: pizza03_0009.jpg
# Captured image: pizza03_0010.jpg
# Captured image: pizza03_0011.jpg
# Captured image: pizza03_0012.jpg
# Captured image: pizza03_0013.jpg
# Captured image: pizza03_0014.jpg
# Captured image: pizza03_0015.jpg
# Captured image: pizza03_0016.jpg
# Captured image: pizza03_0017.jpg
# Captured image: pizza03_0018.jpg
# Captured image: pizza03_0019.jpg
# Captured image: pizza03_0020.jpg
# Captured image: pizza03_0021.jpg
# Captured image: pizza03_0022.jpg
# Captured image: pizza03_0023.jpg
# Captured image: pizza03_0024.jpg
# Captured image: pizza03_0025.jpg
# Captured image: pizza03_0026.jpg
# Captured image: pizza03_0027.jpg
# Captured image: pizza03_0028.jpg
# Captured image: pizza03_0029.jpg
# Captured image: pizza03_0030.jpg
# Captured image: pizza03_0031.jpg
# Captured image: pizza03_0032.jpg
# Captured image: pizza03_0033.jpg
# Captured image: pizza03_0034.jpg
# Captured image: pizza03_0035.jpg
# Captured image: pizza03_0036.jpg
# Captured image: pizza03_0037.jpg
# Captured image: pizza03_0038.jpg
# Captured image: pizza03_0039.jpg
# Captured image: pizza03_0040.jpg
# Captured image: pizza03_0041.jpg
# Captured image: pizza03_0042.jpg
# Captured image: pizza03_0043.jpg
# Captured image: pizza03_0044.jpg
# Captured image: pizza03_0045.jpg
# Captured image: pizza03_0046.jpg
# Captured image: pizza03_0047.jpg
# Captured image: pizza03_0048.jpg
# Captured image: pizza03_0049.jpg
# Captured image: pizza03_0050.jpg
# Captured image: pizza03_0051.jpg
# Captured image: pizza03_0052.jpg
# Captured image: pizza03_0053.jpg
# Captured image: pizza03_0054.jpg
# Captured image: pizza03_0055.jpg
# Captured image: pizza03_0056.jpg
# Captured image: pizza03_0057.jpg
# Captured image: pizza03_0058.jpg
# Captured image: pizza03_0059.jpg
# Captured image: pizza03_0060.jpg
# Captured image: pizza03_0061.jpg
# Captured image: pizza03_0062.jpg
# Captured image: pizza03_0063.jpg
# Captured image: pizza03_0064.jpg
# Captured image: pizza03_0065.jpg
# Captured image: pizza03_0066.jpg
# Captured image: pizza03_0067.jpg
# Captured image: pizza03_0068.jpg
# Captured image: pizza03_0069.jpg
# Captured image: pizza03_0070.jpg
# Captured image: pizza03_0071.jpg
# Captured image: pizza03_0072.jpg
# Captured image: pizza03_0073.jpg
# Captured image: pizza03_0074.jpg
# Captured image: pizza03_0075.jpg
# Captured image: pizza03_0076.jpg
# Captured image: pizza03_0077.jpg
# Captured image: pizza03_0078.jpg
# Captured image: pizza03_0079.jpg
# Captured image: pizza03_0080.jpg
# Captured image: pizza03_0081.jpg
# Captured image: pizza03_0082.jpg
# Captured image: pizza03_0083.jpg
# Captured image: pizza03_0084.jpg
# Captured image: pizza03_0085.jpg
# Captured image: pizza03_0086.jpg
# Captured image: pizza03_0087.jpg
# Captured image: pizza03_0088.jpg
# Captured image: pizza03_0089.jpg
# Captured image: pizza03_0090.jpg
# Captured image: pizza03_0091.jpg
# Captured image: pizza03_0092.jpg
# Captured image: pizza03_0093.jpg
# Captured image: pizza03_0094.jpg
# Captured image: pizza03_0095.jpg
# Captured image: pizza03_0096.jpg
# Captured image: pizza03_0097.jpg
# Captured image: pizza03_0098.jpg
# Captured image: pizza03_0099.jpg
# Captured image: pizza03_0100.jpg
# Captured image: pizza03_0101.jpg
# Captured image: pizza03_0102.jpg
# Captured image: pizza03_0103.jpg
# Captured image: pizza03_0104.jpg
# Captured image: pizza03_0105.jpg
# Captured image: pizza03_0106.jpg
# Captured image: pizza03_0107.jpg
# Captured image: pizza03_0108.jpg
# Captured image: pizza03_0109.jpg
# Captured image: pizza03_0110.jpg
# Captured image: pizza03_0111.jpg
# Captured image: pizza03_0112.jpg
# Captured image: pizza03_0113.jpg
# Captured image: pizza03_0114.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 28
#      25     break
#      27 # 读取一帧图像
# ---> 28 ret, frame = cap.read()
#      30 if ret:
#      31     # 获取当前时间
#      32     current_time = time.time()
#
# KeyboardInterrupt:
